# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ordinary-Least-Squares-(OLS)" data-toc-modified-id="Ordinary-Least-Squares-(OLS)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ordinary Least Squares (OLS)</a></span><ul class="toc-item"><li><span><a href="#Modules" data-toc-modified-id="Modules-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Modules</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Reading-in-the-data" data-toc-modified-id="Reading-in-the-data-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Reading in the data</a></span></li><li><span><a href="#Variable-selection" data-toc-modified-id="Variable-selection-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Variable selection</a></span></li><li><span><a href="#Missing-data" data-toc-modified-id="Missing-data-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Missing data</a></span><ul class="toc-item"><li><span><a href="#Handling-missing-data" data-toc-modified-id="Handling-missing-data-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>Handling missing data</a></span></li></ul></li><li><span><a href="#Data-types" data-toc-modified-id="Data-types-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Data types</a></span><ul class="toc-item"><li><span><a href="#variable-transformation" data-toc-modified-id="variable-transformation-1.2.4.1"><span class="toc-item-num">1.2.4.1&nbsp;&nbsp;</span>variable transformation</a></span></li></ul></li></ul></li><li><span><a href="#Explanatory-analysis" data-toc-modified-id="Explanatory-analysis-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Explanatory analysis</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-dependent-variable" data-toc-modified-id="Distribution-of-dependent-variable-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Distribution of dependent variable</a></span></li><li><span><a href="#Bivariate-analysis:-Exploring-the-relationship-betweeen-dependent-and-independent-variables" data-toc-modified-id="Bivariate-analysis:-Exploring-the-relationship-betweeen-dependent-and-independent-variables-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Bivariate analysis: Exploring the relationship betweeen dependent and independent variables</a></span></li></ul></li><li><span><a href="#Fitting-the-model" data-toc-modified-id="Fitting-the-model-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Fitting the model</a></span><ul class="toc-item"><li><span><a href="#Base-model" data-toc-modified-id="Base-model-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Base model</a></span></li><li><span><a href="#Intepreting-categorical-factors-in-the-model" data-toc-modified-id="Intepreting-categorical-factors-in-the-model-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Intepreting categorical factors in the model</a></span></li><li><span><a href="#Interpreting-non-linear-terms-of-the-independent-variable" data-toc-modified-id="Interpreting-non-linear-terms-of-the-independent-variable-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Interpreting non linear terms of the independent variable</a></span></li></ul></li><li><span><a href="#Model-diagnostic" data-toc-modified-id="Model-diagnostic-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Model diagnostic</a></span><ul class="toc-item"><li><span><a href="#Reproducing-the-mplot-Function-in-R" data-toc-modified-id="Reproducing-the-mplot-Function-in-R-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Reproducing the mplot Function in R</a></span></li><li><span><a href="#Checking-the-functional-form-of-the-model" data-toc-modified-id="Checking-the-functional-form-of-the-model-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Checking the functional form of the model</a></span><ul class="toc-item"><li><span><a href="#Checking-graphically-from-Residuals-Vs-Fitted-plot" data-toc-modified-id="Checking-graphically-from-Residuals-Vs-Fitted-plot-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>Checking graphically from Residuals Vs Fitted plot</a></span></li><li><span><a href="#Using-the-Regression-Specification-Error-Test-(RESET)" data-toc-modified-id="Using-the-Regression-Specification-Error-Test-(RESET)-1.5.2.2"><span class="toc-item-num">1.5.2.2&nbsp;&nbsp;</span>Using the Regression Specification Error Test (RESET)</a></span></li><li><span><a href="#Using-the-polynomials-of-fitted-values" data-toc-modified-id="Using-the-polynomials-of-fitted-values-1.5.2.3"><span class="toc-item-num">1.5.2.3&nbsp;&nbsp;</span>Using the polynomials of fitted values</a></span></li></ul></li><li><span><a href="#Normality-test" data-toc-modified-id="Normality-test-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Normality test</a></span><ul class="toc-item"><li><span><a href="#Graphically-using-the-qqplot" data-toc-modified-id="Graphically-using-the-qqplot-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>Graphically using the qqplot</a></span></li></ul></li><li><span><a href="#Testing-for-heteroscedasticity" data-toc-modified-id="Testing-for-heteroscedasticity-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Testing for heteroscedasticity</a></span><ul class="toc-item"><li><span><a href="#Method-1:-Using-the-scale-location-plot" data-toc-modified-id="Method-1:-Using-the-scale-location-plot-1.5.4.1"><span class="toc-item-num">1.5.4.1&nbsp;&nbsp;</span>Method 1: Using the scale-location plot</a></span></li><li><span><a href="#Checking-for-heteroscedasticity-using-the-Breusch-Pagan-test" data-toc-modified-id="Checking-for-heteroscedasticity-using-the-Breusch-Pagan-test-1.5.4.2"><span class="toc-item-num">1.5.4.2&nbsp;&nbsp;</span>Checking for heteroscedasticity using the Breusch-Pagan test</a></span></li><li><span><a href="#Checking-for-heteroscedasticity-manually" data-toc-modified-id="Checking-for-heteroscedasticity-manually-1.5.4.3"><span class="toc-item-num">1.5.4.3&nbsp;&nbsp;</span>Checking for heteroscedasticity manually</a></span></li></ul></li></ul></li><li><span><a href="#Dealing-with-heteroscedasticity" data-toc-modified-id="Dealing-with-heteroscedasticity-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Dealing with heteroscedasticity</a></span><ul class="toc-item"><li><span><a href="#Checking-for-influential-observations" data-toc-modified-id="Checking-for-influential-observations-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Checking for influential observations</a></span><ul class="toc-item"><li><span><a href="#Method1:-cook's-distance-plot" data-toc-modified-id="Method1:-cook's-distance-plot-1.6.1.1"><span class="toc-item-num">1.6.1.1&nbsp;&nbsp;</span>Method1: cook's distance plot</a></span></li><li><span><a href="#Method2:-residual-vs-Leverage-plot" data-toc-modified-id="Method2:-residual-vs-Leverage-plot-1.6.1.2"><span class="toc-item-num">1.6.1.2&nbsp;&nbsp;</span>Method2: residual vs Leverage plot</a></span></li></ul></li><li><span><a href="#Dealing-with-heteroscedasticity-in-the-absence-of-influential-outliers" data-toc-modified-id="Dealing-with-heteroscedasticity-in-the-absence-of-influential-outliers-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Dealing with heteroscedasticity in the absence of influential outliers</a></span><ul class="toc-item"><li><span><a href="#Robust-standard-error" data-toc-modified-id="Robust-standard-error-1.6.2.1"><span class="toc-item-num">1.6.2.1&nbsp;&nbsp;</span>Robust standard error</a></span></li><li><span><a href="#Weighted-Least-Squares-(WLS)" data-toc-modified-id="Weighted-Least-Squares-(WLS)-1.6.2.2"><span class="toc-item-num">1.6.2.2&nbsp;&nbsp;</span>Weighted Least Squares (WLS)</a></span></li></ul></li></ul></li><li><span><a href="#Reporting-the-confidence-intervals-for-the-chosen-model" data-toc-modified-id="Reporting-the-confidence-intervals-for-the-chosen-model-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Reporting the confidence intervals for the chosen model</a></span></li><li><span><a href="#Displaying-all-the-models-in-one-table" data-toc-modified-id="Displaying-all-the-models-in-one-table-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Displaying all the models in one table</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Ordinary Least Squares (OLS)
# - So I have been reading the textbook [**Introductory Economics: A Modern Approach** by Jeffrey M.Wooldridge](https://www.amazon.com/Introductory-Econometrics-Modern-Approach-Economics/dp/1111531048) and in this project, I will be implementing the ordinary least squares model based on the literature in the textbook
# - My focus will be on the underlying asusumptions, specification, estimation, interpretation as well as diagnostic checks of an OLS model

# %% [markdown]
# ## Modules

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings as warnings
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.stats.diagnostic as dg
import re
import math

from stargazer.stargazer import Stargazer 
from statsmodels.nonparametric.smoothers_lowess import lowess
from matplotlib import collections as matcoll
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
from termcolor import colored
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data
# Reference to the data set:
# *Mroz, T.A. (1987): "The Sensitiviy of an Empirical Model of Married Women's Hours of Work to Economic and Statistical Assumptions", Econometrica, 55, 765-799.*
# - **Variable description**
#     - exper - experience
#     - expersq - experience squared
#     - educ - education in years
#     - age
#     - kidslt6 - number of kids less than 6 years old
#     - kidsge6 - number of kids older than 6 years

# %% [markdown]
# ### Reading in the data

# %%
df = pd.read_stata('http://fmwww.bc.edu/ec-p/data/wooldridge/mroz.dta')

# %%
df.head(1);

# %% [markdown]
# ### Variable selection
# The initial dataset has very may variables but inline with the textbook, we are only interested in afew select vaiables

# %%
cols = ['lwage', 'exper', 'expersq', 'educ',  'age', 'kidslt6', 'kidsge6']
df_v1 = df[cols]

# %%
df_v1.head(1);

# %% [markdown]
# ### Missing data

# %%
pd.DataFrame(df_v1.isnull().sum()).transpose();

# %% [markdown]
# - ***Observation:*** *Missing data in lwage*

# %% [markdown]
# #### Handling missing data
# - Lwage is the dependent variable and there is no specific about the independent features for the subjects were wage is missing, hence I just exclude those subjects from the study

# %%
# missing flag
df_v1['MissingFlag'] = df_v1['lwage'].apply(lambda x: 'Y' if math.isnan(x) else 'N')

plt.style.use('ggplot')
sns.displot(x='exper'
            ,data=df_v1
            ,hue='MissingFlag'
            ,kind='kde'
            ,fill=True
            ,height=5
            ,aspect=2
            ,palette={'N':'deepskyblue', 'Y':'red'}
           )
plt.title('Understanding missing data within different features', fontsize=14, fontweight='bold', fontname='Georgia')
plt.xlabel('Expeience', fontsize=12, fontweight='bold')
plt.ylabel('')
plt.tick_params(axis='y', which='major' ,left=False, labelleft=False)
plt.show()

# %% [markdown]
# ***Observation:***
# - Missing data is more among people with no or less experience, I will drop all subjects where data on wage is missing . The implication might be that the results of the model may not generalize well to people with no or very little experience

# %%
df_v1.dropna(how='any' ,inplace=True)
df_v1.drop('MissingFlag' ,axis=1 ,inplace=True)

# %% [markdown]
# ### Data types

# %%
pd.DataFrame(df_v1.dtypes).transpose();

# %% [markdown]
# #### variable transformation
# - So far every variable has been pesented on a continous scale, but we can represent things like education as ordinal categorical variable

# %%
df_v1['educgr'] = pd.cut(df_v1['educ']
                         ,bins = [5,11,13, 18]
                         ,labels=('Diploma','Degree','Masters')
                         ,ordered=True
                        )

# %% [markdown]
# ## Explanatory analysis
# ### Distribution of dependent variable

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df_v1
             ,x='lwage'
             ,color='deepskyblue'
             ,bins=50
             ,kde=True
            )
plt.title('Distribution of wage', fontsize=16, fontweight='bold', fontname='Georgia')
plt.xlabel('log(wage)', fontsize=12, fontweight='bold')
plt.ylabel('Count', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ### Bivariate analysis: Exploring the relationship betweeen dependent and independent variables

# %%
sns.displot(data = df_v1
            ,x="lwage"
            ,hue="educgr"
            ,kind="kde"
            ,fill=True
            ,height=6
            ,aspect=1.5
            ,palette={'Diploma':'#ff2e63', 'Degree':'deepskyblue', 'Masters':'#01949A'}
           )
plt.xlabel('lwage', fontsize= 14, fontweight = 'bold')
plt.ylabel('Density', fontsize= 14, fontweight = 'bold')
plt.title('Distribution of wage by level of education', fontsize=16, fontweight='bold', fontname='Georgia')
plt.xlabel('log(wage)', fontsize=12, fontweight='bold')
plt.tick_params(axis='y' ,which='major' ,left=False ,labelleft=False)
plt.xlabel('')
plt.show()

# %% [markdown]
# ***Observations:***
# - *People people have degrees and people with degrees on average earn relatively the same compared to people with diplomas or masters*

# %% [markdown]
# ## Fitting the model

# %% [markdown]
# ### Base model

# %%
Base_model = smf.ols('lwage ~ exper  + educ + age + kidslt6 + kidsge6', data = df_v1).fit()

# %%
print(Base_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     14.98
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           1.52e-13
# Time:                        15:43:05   Log-Likelihood:                -433.15
# No. Observations:                 428   AIC:                             878.3
# Df Residuals:                     422   BIC:                             902.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2190      0.300     -0.729      0.466      -0.809       0.371
# ...

# %% [markdown]
# - **Interpretation:**
#     - ***R-squared:*** *Model explains approximately 15% of the variation in wage*
#     - ***Prob (F-statistic):*** *The coefficients are collectivelt significant at 5% level of significance*
#     - ***Coef P-values:*** *Experience, education are statistically significant in predicting wage at 5% level of significance*
#         - *Increase in the level of education by 1 unit while keeping other factors constant on average increases wage  by 11%*
#         - *Increase in experience by 1 unit while keeping other factors constant on average increases wage by approximately 1.6%
#     - ***Prob(Omnibus):*** *Residuals not notmally distributed*
#     - ***Durbin-Watson:*** *No auto-correlation*
#     - ***Cond. No:*** *No multicollinearity between independent variables*

# %% [markdown]
# ### Intepreting categorical factors in the model
# - The categories are intepreted with respect to the base category which is excluded from the model
# - I replace the numeric education variable with the category education variable I created

# %%
# model with categorical data
Category_model = smf.ols('lwage ~ exper + educgr + age + kidslt6 + kidsge6', data = df_v1).fit()

# %%
print(Category_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     9.262
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           1.53e-09
# Time:                        15:44:34   Log-Likelihood:                -440.76
# No. Observations:                 427   AIC:                             895.5
# Df Residuals:                     420   BIC:                             923.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.9455      0.248      3.818      0.000       0.459       1.432
# ...

# %% [markdown]
# ***Interpretation:***
# - *Peope with degrees on average earn 25% more wage than those with diplomas*
# - *Peope masters on average earn 62% more wage than those with diplomas*

# %% [markdown]
# ### Interpreting non linear terms of the independent variable
# - The interpretation of the estimates has so far been straight forard becasue the model specification inlcudes only linear terms, however the case is not the same when we have non-linear terms such as polynomials of independent variables
#     - I add experience squared Polynomials of order 2) to the base model and investigate impact

# %%
# model with non-linear terms
NonLinear_model = smf.ols('lwage ~ exper + I(exper**2)  + educ + age + kidslt6 + kidsge6', data = df_v1).fit()

# %%
print(NonLinear_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     13.19
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           1.06e-13
# Time:                        15:57:31   Log-Likelihood:                -431.24
# No. Observations:                 428   AIC:                             876.5
# Df Residuals:                     421   BIC:                             904.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.4209      0.317     -1.328      0.185      -1.044       0.202
# ...

# %% [markdown]
# ***Observation:***
# - With the the presence of both experience and squared experience, the condition number is now very high and the model results warn that there might be multicollinearity. However, this is not a concern for now since the objective is prediction and not the individual impact of each feature
# - I visualize the effects of experience on wage under the current model specification with other factos fixed constant

# %%
# dummy values for experience
df_exp = pd.DataFrame( {'X':np.arange(38)})

# predict wage using experience as the only variable
df_exp['Y'] = df_exp['X'].apply(lambda x: NonLinear_model.params['Intercept'] + NonLinear_model.params['exper']*x + NonLinear_model.params['I(exper ** 2)']*(x**2) + NonLinear_model.params['educ']*12.6 + NonLinear_model.params['age']*42 + NonLinear_model.params['kidslt6']*0.1402 + NonLinear_model.params['kidsge6']*42 )

# show the impact
fig = plt.figure(figsize = (10,6))

sns.lineplot(x = 'X' ,y = 'Y' ,data = df_exp ,color='deepskyblue' )
sns.scatterplot(x = 'X' ,y = 'Y' ,data = df_exp ,color='deepskyblue' ,s=60 )
plt.ylabel('log(wage)', fontsize=12, fontweight='bold')
plt.xlabel('experience', fontsize=12, fontweight='bold')
plt.title('Estimated impact of experience on wage', fontsize=18, fontweight='bold', fontname='Georgia')
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %% [markdown]
# ## Model diagnostic
# - OLS model has some underlying assumptions some of which if violated may result into biased estimates or cause OLs to not be the best linear unbiased estimator (BLUE). In the following section, I investigate the fulfillment of those assumptions

# %% [markdown]
# ### Reproducing the mplot Function in R
# - R has a library called mplot which ha smany methods for visualizing many diagnostic checks that can be performed on OLS models, I recreate some of the methods with this object

# %%
class mplot:
    """
    Description = Reproduces the diagnostic plots in mplot package in R
    
    Parameters:
        1. model results fitted using statsmodels.formula.api
        2. An integer from 1 to 7 that specifies which diagnostic plot to produce
            1. Residuals vs Fitted
            2. Normal Q-Q
            3. Scale-Location
            4. Cook's Distance
            5. Residuals vs Leverage
            6. Cook's dist vs Leverage
            7. 95% confidence intervals
    Modules it 
        1. import pandas as pd
        2. import numpy as np
        3. import statsmodel.formula.api as smf
        4. from from statsmodels.nonparametric.smoothers_lowess import lowess
        5. import statsmodels.api as sm
        6. from matplotlib import collections as matcoll
    """
    
    def __init__(self, mdl, n):
        self.mdl = mdl
        self.n = n
        # fitted values
        self.fitted_values = pd.Series(self.mdl.fittedvalues)
        self.res_df = pd.DataFrame(self.fitted_values, index = self.mdl.fittedvalues.index, columns = ['fitted_values'])
        # residuals
        self.res_df['residuals'] = self.mdl.resid
        # Standardized (studentized) residuals
        self.res_df['student_residuals'] = self.mdl.get_influence().resid_studentized_internal
        # square rootof studentized residuals 
        self.res_df['sqrt_student_residuals'] = np.sqrt(np.abs(self.res_df['student_residuals']))
        # leverage
        self.res_df['leverage'] = self.mdl.get_influence().hat_matrix_diag

        # cooks distance
        self.res_df['cooks_distance'] = self.mdl.get_influence().cooks_distance[0]
        
        # parameter details
        self.df_params = pd.DataFrame(self.mdl.params.reset_index())
        self.df_params.columns = ['var', 'coef']
        self.df_params['errors'] = self.df_params['coef'] - self.mdl.conf_int().iloc[:,0].values
        self.df_params['pvalues'] = self.mdl.pvalues.values
        self.df_params['Significant'] = self.df_params['pvalues'] < 0.05
        #self.df_params.sort_values(by='coef', ascending = True, inplace = True)
        
    def plot(self):
        
        plt.style.use('ggplot')
        
        if self.n == 1:
            fig, ax = plt.subplots(figsize = (10,5))
            
            # rows with top residuals 
            top3 = abs(self.res_df['residuals']).sort_values(ascending = False)[:3]
            
            # x - cordinates
            X = self.res_df['fitted_values']
            # y - cordinates
            Y = self.res_df['residuals']
            # smoothened values for the regplot
            smoothed = lowess(self.res_df['residuals'],self.res_df['fitted_values'])
            
            #plotting
            
            ax.scatter(X, Y, linewidth = 3, alpha = 0.85, s = 6)
            ax.plot(smoothed[:,0], smoothed[:,1], color = 'k')
            ax.set_ylabel('Residuals', fontsize = 12, fontweight = 'bold')
            ax.set_xlabel('Fitted Values', fontsize = 12, fontweight = 'bold')
            ax.set_title('Residuals vs. Fitted', fontsize = 14, fontweight = 'bold')
            ax.plot([min(X),max(X)],[0,0],color = 'k',linestyle = ':', alpha = .8)
            for i in top3.index:
                ax.annotate(i,
                            xy=(X[i], Y[i]),
                            fontsize = 10, color = 'k', fontweight = 'bold'
                           )
            return plt.show()  
        
        if self.n == 2:
            fig, ax = plt.subplots(figsize = (10,5))
            Y = self.res_df['residuals']
           
            # qq plot from statsmodels.api = sm
            QQplot = sm.qqplot(Y, fit = True, line = "q",ax = ax)
            # qqplot title
            QQplot.axes[0].set_title('Normal Q-Q', fontsize = 14, fontweight = 'bold')
            # x_axis title
            QQplot.axes[0].set_xlabel('Theoretical Quantiles', fontsize = 12, fontweight = 'bold')
            # y_axis title
            QQplot.axes[0].set_ylabel('Standardized Residuals', fontsize = 12, fontweight = 'bold')
            
            # Annotation
            # top residuals from the plot
            locator = np.arange(3)-3
            # get plot x and y values
            axes = plt.gca()
            line = axes.lines[0]
            x_values = line.get_xdata()
            y_values = line.get_ydata()
            for i, j in enumerate(locator):
                indx = np.argsort(np.abs(Y)).values[j]
                QQplot.axes[0].annotate(indx,
                                        xy = (x_values[j], y_values[j]),
                                        fontsize = 10, color = 'k', fontweight = 'bold'
                                       )  
            return plt.show() 
        
        if self.n == 3:
            fig, ax = plt.subplots(figsize = (10,5))
            X = self.res_df['fitted_values']
            Y = self.res_df['sqrt_student_residuals']
            smoothed = lowess(Y,X)

            # rows with top residuals 
            top3 = abs(self.res_df['residuals']).sort_values(ascending = False)[:3]
            
            ax.scatter(X, Y, alpha = 0.85, linewidths = 3,color = 'r', s = 6)
            ax.plot(smoothed[:,0],smoothed[:,1],color = 'k');
            ax.set_ylabel('$\sqrt{Studentized \ Residuals}$', fontsize = 12, fontweight = 'bold')
            ax.set_xlabel('Fitted Values', fontsize = 12, fontweight = 'bold')
            ax.set_title('Scale-Location', fontsize = 14, fontweight = 'bold')
            ax.set_ylim(0,max(Y)+0.1)
            for i in top3.index:
                ax.annotate(i,
                            xy = (X[i],Y[i]),
                            fontsize = 10, color = 'k', fontweight = 'bold'
                           )
            return plt.show()  
        
        if self.n == 4:  
            
            # cordinates
            df_res = self.res_df.reset_index().drop('index', axis=1)
            X = df_res.index
            Y = df_res['cooks_distance']
            
            # rows with the highest cook distance
            top3 = abs(df_res['cooks_distance']).sort_values(ascending = False)[:3]

            # creates cordinates for vertical lines
            lines = []
            for i in range(len(X)):
                pair = [(X[i],0), (X[i], Y[i])]
                lines.append(pair)
            linecoll = matcoll.LineCollection(lines)
            
            # plot
            fig, ax = plt.subplots(figsize = (10,5))
            ax.add_collection(linecoll)
            plt.scatter(X,Y, alpha = 0.85, linewidths = 3,color = 'r', s = 6)
            ax.set_ylabel("Cook's distance", fontsize = 12, fontweight = 'bold')
            ax.set_xlabel('Observation number', fontsize = 12, fontweight = 'bold')
            # annotation
            for i in top3.index:
                ax.annotate(i,
                            xy = (X[i],Y[i]),
                            fontsize = 10, color = 'k', fontweight = 'bold'
                           )
            return plt.show()

        if self.n == 5: 
            
            # studentized residuals
            student_residuals = pd.Series(self.mdl.get_influence().resid_studentized_internal)
            student_residuals.index = self.mdl.resid.index
            df = pd.DataFrame(student_residuals)
            df.columns = ['student_residuals']
            # leverage
            df['leverage'] = self.mdl.get_influence().hat_matrix_diag
            
            # top 3
            sorted_student_residuals = abs(df['student_residuals']).sort_values(ascending = False)
            top3 = sorted_student_residuals[:3]

            # cordinates
            x = df['leverage']
            y = df['student_residuals']
            smoothed = lowess(y, x)
            
            # plot
            fig, ax = plt.subplots(figsize = (8,5))
            ax.scatter(x, y, linewidths = 3,color = 'r', s = 6)
            ax.plot(smoothed[:,0],smoothed[:,1],color = 'k')
            ax.set_ylabel('Studentized Residuals', fontsize = 12, fontweight = 'bold')
            ax.set_xlabel('Leverage', fontsize = 12, fontweight = 'bold')
            ax.set_title('Residuals vs. Leverage', fontsize = 14, fontweight = 'bold')
            ax.set_ylim(min(y)-abs(min(y))*0.25,max(y)+max(y)*0.15)
            ax.set_xlim(-0.01,max(x)+max(x)*0.05)
            plt.tight_layout()
            for val in top3.index:
                ax.annotate(val,
                            xy = (x.loc[val],y.loc[val]),
                            fontsize = 10, color = 'k', fontweight = 'bold'
                           )

            xpos = max(x)+max(x)*0.01  
            cooksx = np.linspace(min(x), xpos, 50)
            p = len(self.mdl.params)
            poscooks1y = np.sqrt((p*(1-cooksx))/cooksx)
            poscooks05y = np.sqrt(0.5*(p*(1-cooksx))/cooksx)
            negcooks1y = -np.sqrt((p*(1-cooksx))/cooksx)
            negcooks05y = -np.sqrt(0.5*(p*(1-cooksx))/cooksx)
            ax.plot(cooksx,poscooks1y,label = "Cook's Distance", ls = ':', color = 'r')
            ax.plot(cooksx,poscooks05y, ls = ':', color = 'r')
            ax.plot(cooksx,negcooks1y, ls = ':', color = 'r')
            ax.plot(cooksx,negcooks05y, ls = ':', color = 'r')
            ax.plot([0,0],ax.get_ylim(), ls=":", alpha = .3, color = 'k')
            ax.plot(ax.get_xlim(), [0,0], ls=":", alpha = .3, color = 'k')
            ax.annotate('1.0', xy = (xpos, poscooks1y[-1]), color = 'r')
            ax.annotate('0.5', xy = (xpos, poscooks05y[-1]), color = 'r')
            ax.annotate('1.0', xy = (xpos, negcooks1y[-1]), color = 'r')
            ax.annotate('0.5', xy = (xpos, negcooks05y[-1]), color = 'r')
            ax.legend()
            
            return plt.show()


        if self.n == 6: 
            fig, ax = plt.subplots(figsize = (10,5))
            # cordinates
            X = self.res_df['leverage']
            Y = self.res_df['cooks_distance']
            smoothed = lowess(Y,X)
            
            # rows with highest cooks distance
            top3 = abs(Y).sort_values(ascending = False)[:3]

            # plot
            ax.scatter(X, Y, alpha = 0.85, linewidths = 3,color = 'r', s = 6)
            ax.plot(smoothed[:,0],smoothed[:,1],color = 'k')
            ax.set_ylabel("Cook's distance", fontsize = 12, fontweight = 'bold')
            ax.set_xlabel('Leverage', fontsize = 12, fontweight = 'bold')
            ax.set_title("Cook's dist vs. Leverage", fontsize = 14, fontweight = 'bold')
            # annotation
            for i in top3.index:
                ax.annotate(i,
                            xy = (X.loc[i],Y.loc[i]),
                            fontsize = 10, color = 'k', fontweight = 'bold'
                           )
            return plt.show()
        
        if self.n == 7: 
            fig, ax = plt.subplots(figsize = (10,8))

            self.df_params.plot(x = 'var', y = 'coef',
                           kind = 'barh',
                           ax = ax, color = 'none', fontsize = 22, 
                           ecolor = self.df_params.Significant.map({True: '#20B2AA', False: '#F08080'}),
                           capsize = 0,
                           xerr = 'errors', 
                           legend = False
                          )
            # locate the coefficients on the confidence interval
            ax.scatter(y = pd.np.arange(self.df_params.shape[0]), 
                       marker = 'o',
                       s = 160, 
                       x = self.df_params['coef'], 
                       color = self.df_params.Significant.map({True: '#20B2AA', False: '#F08080'}),
                      )

            # the zero axis line
            ax.axvline(x = 0, linestyle = '--', color = '#F08080', linewidth = 1)

            # plot title
            plt.title('95% confidence intervals', fontsize = 16, fontweight = 'bold')

            # font sizes for the axis
            ax.tick_params(axis = 'both', which = 'major', labelsize = 10)

            # font size for the coefficients
            ax.set_ylabel('Coefficients',fontsize = 12, fontweight = 'bold')

            # font size for the variables
            ax.set_xlabel('estimates',fontsize = 12, fontweight = 'bold')

            return plt.show()
        
    def df_resid(self):
        return self.res_df
            
    def df_params(self):
        return self.df_params

# %% [markdown]
# ### Checking the functional form of the model
# - The first thing I check for is whether the model is well specified. a come thing to check is if there are some non-linear terms in the model. Three approaches are  suggested in the book;
#     1. By inspection graphically
#     2. Using the RESET test
#     3. Add polynomials of fitted values to the model, some non-linearity should be added to the model if the fitted values have predictive power

# %% [markdown]
# #### Checking graphically from Residuals Vs Fitted plot
# If the model is properly specified, Residuals vs Fitted plot will look like random noise; there won’t be any apparent patterns in the scatterplot

# %%
mplot(Base_model, 1).plot()

# %% [markdown]
# ***Observation***
# - *the horizontol line is fairly flat which suggests that the model is not missing non linear terms*

# %% [markdown]
# #### Using the Regression Specification Error Test (RESET)
# The null hypothesis is that the model with only linear terms is correctly specifiec; which is to say that coefficient of any polynomial of the fitted values if added to the model is zero

# %%
import statsmodels.stats.diagnostic as dg

# function to check function form at 5% level of significance
def funcheck(mdl, pwr):
    p_value = round(float(dg.linear_reset(mdl, power = pwr, test_type = 'fitted', use_f = True).pvalue), 3)
    
    if p_value < 0.05:
        print('P_value = {}: We reject the null hypothesis that the current specification is correct'.format(p_value))
    else:
        print('P_value = {}: We fail to reject the null hypothesis that the current specification is correct'.format(p_value))

# %%
funcheck(Base_model, [2,3])
# Out:
# P_value = 0.171: We fail to reject the null hypothesis that the current specification is correct

# %% [markdown]
# #### Using the polynomials of fitted values
# The polynomials of the fitted values should not have any predictive power in the model otherwise the model is missing some non-linearity terms

# %%
# function to check for non-linearity using polynomials of fitted values
def funcheck_poly(df1, dep_var, ind_vars):
    
    df = df1.copy()
    # df isa dataframe
    # dep_var is a string name for the dependent variable
    # ind_vars is a list of regressors
    
    # formula for regressors
    X = " + ".join(ind_vars)
    
    # full model formula to be passed to the model
    model_formula = dep_var + ' ~ ' + X
    
    # fitting the model using statsmodel.formula.api=smf
    model_init = smf.ols(model_formula, data = df).fit()
    
    # getting fitted values
    df['model_pred'] = model_init.predict(df)
    
    # formula with polynomials of fitted values
    model_formula_1 = model_formula + ' + I(model_pred**2) + I(model_pred**3)'
    
    # model with fitted values
    model_poly = smf.ols(model_formula_1, data = df).fit()
    
    # output p_values of the polynomials
    print(model_poly.pvalues.loc['I(model_pred ** 2)':'I(model_pred ** 3)'])
    
    # conclusion
    p2_pvalue, p3_pvalue  = model_poly.pvalues.loc['I(model_pred ** 2)'], model_poly.pvalues.loc['I(model_pred ** 3)']
    if (p2_pvalue < 0.05 or p3_pvalue < 0.05):
        print('Non-linearity missing in the model')
    elif (p2_pvalue >= 0.05 and p3_pvalue >= 0.05):
        print('Non-linearity not missing in the model')
    
    return model_poly

# %%
# testing for functional form
# List of regressors
ind_vars = ['exper', 'educ', 'age', 'kidslt6', 'kidsge6']

# checking
LnrCheck_model = funcheck_poly(df_v1, 'lwage', ind_vars)
# Out:
# I(model_pred ** 2)    0.763657
# I(model_pred ** 3)    0.600254
# dtype: float64
# Non-linearity not missing in the model

# %%
print(LnrCheck_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     11.24
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           4.47e-13
# Time:                        17:10:34   Log-Likelihood:                -431.34
# No. Observations:                 428   AIC:                             878.7
# Df Residuals:                     420   BIC:                             911.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0990      1.523      0.065      0.948      -2.895       3.093
# ...

# %% [markdown]
# ### Normality test
# OLS assumes that the residuals are normally distributed with mean 0 and constant variance $ \sigma^2 $. We can check for normality of the error terms by:
# 1. Inspecting graphically using the qqplot
# 2. Statistical tests

# %% [markdown]
# #### Graphically using the qqplot
# - The residuals should be distributed along the straight line

# %%
mplot(Base_model,2).plot()

# %% [markdown]
# ***Observation*** *We have some extreme values on both sides which suggests that the errors are not normally distributed*
# - normal distribution of the residuals is a good to have requirement but not a must to have

# %% [markdown]
# ### Testing for heteroscedasticity
# OLS assumes that the residuals are normally distributed with mean 0 and constant variance $ \sigma^2 $ (homoscedasticity). We can check for homoscedasticity of the error terms by:
# 1. Inspecting graphically using the scale-location plot
# 2. Statistical tests
# 3. Predict squares of the residuals using the independent variables, reject the null hypothesis that the residuals are homoscedastic if any of the independent variables is significant in predicting the squares of the residuals

# %% [markdown]
# #### Method 1: Using the scale-location plot

# %%
mplot(Base_model,3).plot()

# %% [markdown]
# ***interpretation :-*** *there appears an upward trend in the lowess smoother for higher fitted values which suggest that there might be heteroscedasiticity*
# - To confirm the presence or absence of heteroscedasticity, we need to perform statistical tests.
#     - In the section below, we test for this using the **Breusch pagan** test

# %% [markdown]
# #### Checking for heteroscedasticity using the Breusch-Pagan test

# %% [markdown]
# ##### Function for implementing the Breusch-Pagan test

# %%
def bt_test(mdl):
    
    # test using statsmodels.stats.api = sms
    bp_test = sms.het_breuschpagan(mdl.resid, mdl.model.exog)
    
    # round off
    bp_test = list(map(lambda x: round(x,3), bp_test))
    
    # conclusion
    if bp_test[1] < 0.05:
        print('The lagrange multiplier statistic is: {}\nThe Lagrange multiplier p_value is {}\nWe reject the null hypothesis that homoscedasticity is present'.format(bp_test[0], bp_test[1]))
    elif bp_test[1] >= 0.05:
        print('The lagrange multiplier statistic is: {}\nThe Lagrange multiplier p_value is {}\nWe fail to reject the null hypothesis that homoscedasticity is present'.format(bp_test[0], bp_test[1]))
    
    return list(map(lambda x: round(x,3), bp_test))

# %%
# papplying function to test for heteroscedasticity
bttest_results = bt_test(Base_model)
# Out:
# The lagrange multiplier statistic is: 13.794
# The Lagrange multiplier p_value is 0.017
# We reject the null hypothesis that homoscedasticity is present

# %% [markdown]
# #### Checking for heteroscedasticity manually

# %%
def heterochk(mdl, df1):
    df = df1
    
    # 2. Get the squares of the residuals
    df['resid'] = mdl.resid
    # squares of the residuals
    df['resid_sq']= df['resid']**2

    # getting independent variables included in the model
    cols = set(re.sub( r"(\w+)\[T\..*",r"\1",col) if col.find('T.') else col for col in mdl.params.index if col != 'Intercept')
    
    # formula for independent vars - to be parsed to the model function
    X = " + ".join(cols)
    # full model formula to be passed to the model
    model_formula = 'resid_sq' + ' ~ ' + X
    
    # fitting the model
    model_ = smf.ols(model_formula, data = df).fit()
    
    # drop temporary variables created
    df = df.drop(['resid','resid_sq'], axis=1)
    
    return model_

# %%
HeterCheck_model = heterochk(Base_model,df_v1)

# %%
print(HeterCheck_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               resid_sq   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     2.811
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):             0.0164
# Time:                        17:23:29   Log-Likelihood:                -627.91
# No. Observations:                 428   AIC:                             1268.
# Df Residuals:                     422   BIC:                             1292.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1386      0.473     -0.293      0.770      -1.069       0.792
# ...

# %% [markdown]
# ***Results from manually approach*** *are similar to those from the Breuschpagan test (F_statistics = 2.677 and F_pvalue = 0.015).*
# - *We reject the null hypothesis that there is homoscedasticity*

# %% [markdown]
# ## Dealing with heteroscedasticity
# - All the checks we have performed so far have concluded that there is heteroscedasticity, which means that though our estimator is still consistent and unbiased, it is nolonger efficient (no longer blue). In the sections that follow, I look at ways of dealing with heteroscedasticity

# %% [markdown]
# ### Checking for influential observations
# So far we have checkedfor model specification and concluded that our model is well specified and such the heteroscedasticity we observe can not be explain by model specification. An alternative source of heteroscedasticity is the presence of outliers, so an a next step we exam our data for the presence of outliers or influenctial values

# %% [markdown]
# #### Method1: cook's distance plot
# - **Cook's distance:** Measures how much all the fitted values change when a given observation is deleted
#     - A data point with high cook's distance indicates that the data point strong influences the fitted values
#     - **Identification:**
#         - if the cook's distance is more than 0.5, the data point might be infuential
#         - if the cook's distance is more than 0.5, the data point might be infuential
#         - if the cook's distance stands out more than the other cook's distances, then it is almost certain that it is influential.

# %%
mplot(Base_model,4).plot()

# %% [markdown]
# *Observations 73, 219 and 348 have a cook's distance more than 0.5 and as such might be influential*

# %% [markdown]
# #### Method2: residual vs Leverage plot
# - **Leverage:** Refers to the extent to which the coefficients of the regression model would change if a particular observation was removed from the dataset.
#     - Observations with high leverage have strong influence on the coefficients in the regression model, removing theseobservations might change the coefficients of the model considerably
# - **Identification:**
#     - From the residuals vs leverage points, points that fall outside the cook's distance (red dotted line) are considered to be influential observations
# - **Handling influential observations:**
#     - Verify that the influential observation is not an error
#     - Attempt to fit another regression. Influential observations may indicate that the specified model doesnt fit well the data; adding some nonlinear terms may yield different results
#     - Remove the influential observations if the model seems to fit the data well execpt the influential observation

# %%
mplot(Base_model, 6).plot()

# %% [markdown]
# *There are no observations outside the cook's distance and we can conclude that there are no influential observation*

# %% [markdown]
# ### Dealing with heteroscedasticity in the absence of influential outliers
# - So far from cook's distance and leverage, there is evidence of some extreme values but there is no evidence that these extreme values are actually influenctial. Based on this, we cna handle heteroscedasticity in the following ways
#     1. Report corrected standard errors (Heteroscedasticity robust standard errors)
#     2. Use weighted Least squares

# %% [markdown]
# #### Robust standard error

# %%
Robust_model = smf.ols('lwage ~ exper + I(exper**2) + educ + age + kidslt6 + kidsge6', data = df_v1)
Robust_model = Robust_model.fit(cov_type='HC3', use_t = True)

# %%
print(Robust_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     13.38
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           6.74e-14
# Time:                        17:25:58   Log-Likelihood:                -431.24
# No. Observations:                 428   AIC:                             876.5
# Df Residuals:                     421   BIC:                             904.9
# Df Model:                           6
# Covariance Type:                  HC3
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.4209      0.322     -1.306      0.192      -1.054       0.213
# ...

# %% [markdown]
# ***Observation:*** *The standard erors are now robust and they are relatively large than previously stated*

# %% [markdown]
# #### Weighted Least Squares (WLS)

# %%
# define weights
# convariance matrix
# model6.cov_params()
df_weights = pd.DataFrame({'residuals':abs(Base_model.resid), 'fitted':Base_model.fittedvalues})
model_weights = smf.ols('residuals ~ fitted', data = df_weights).fit().fittedvalues.values
myweight = 1/(model_weights **2)

# %%
WLS_model = smf.wls('lwage ~ exper + I(exper**2) + educ + age + kidslt6 + kidsge6', data = df_v1, weights=myweight)
WLS_model = WLS_model.fit()

# %%
print(WLS_model.summary())
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.168
# Model:                            WLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     14.14
# Date:                Mon, 17 Jan 2022   Prob (F-statistic):           1.10e-14
# Time:                        17:34:24   Log-Likelihood:                -429.52
# No. Observations:                 428   AIC:                             873.0
# Df Residuals:                     421   BIC:                             901.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.3859      0.315     -1.224      0.222      -1.006       0.234
# ...

# %% [markdown]
# ## Reporting the confidence intervals for the chosen model

# %%
mplot(Robust_model,7).plot()

# %% [markdown]
# ## Displaying all the models in one table

# %%
results = Stargazer([Base_model, Category_model, NonLinear_model, Robust_model, WLS_model])

# asign model names
results.custom_columns(
                       # model names
                       ['Base model', 'Model with categorical variables', 'Model with non-linear terms model',
                        'Model with robust standard errors', 'Weighetd Least Squares model'
                       ],
                       [1, 1, 1, 1, 1],
                    )

# remove model numbers
results.show_model_numbers(False)

# show all model results
results
# Out:
# <table style="text-align:center"><tr><td colspan="6" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="5"><em>Dependent variable:lwage</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Base model</td><td colspan="1">Model with categorical variables</td><td colspan="1">Model with non-linear terms model</td><td colspan="1">Model with robust standard errors</td><td colspan="1">Weighetd Least Squares model</td></tr><tr><td colspan="6" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">I(exper ** 2)</td><td></td><td></td><td>-0.001<sup>*</sup></td><td>-0.001<sup>*</sup></td><td>-0.001<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(0.000)</td><td>(0.000)</td><td>(0.000)</td></tr><tr><td style="text-align:left">Intercept</td><td>-0.219<sup></sup></td><td>0.946<sup>***</sup></td><td>-0.421<sup></sup></td><td>-0.421<sup></sup></td><td>-0.386<sup></sup>
# ...
